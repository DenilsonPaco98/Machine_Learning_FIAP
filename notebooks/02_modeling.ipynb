# %% [markdown]
# # Modeling - Churn Prediction
#
# Neste notebook desenvolveremos e compararemos modelos para previsão de churn.

# %% [markdown]
# ## 1. Setup e Imports

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

from src.config import SEED, RAW_DATA_DIR, DATASET_NAME
from src.data.preprocess import load_data, DataPreprocessor
from src.data.splitter import split_train_test, split_train_val
from src.features.build_features import get_feature_importance
from src.models.baseline import DummyBaseline, LogisticBaseline
from src.models.mlp import MLPClassifier
from src.utils.metrics import calculate_metrics

# Set seed
np.random.seed(SEED)
torch.manual_seed(SEED)

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

# %% [markdown]
# ## 2. Load and Prepare Data
#
# ### TODO: Carregar dados
# - Load dataset
# - Preparar features e target
# - Realizar train/test split

# %%
# TODO: Carregar dados com load_data
# TODO: Preparar X e y
# TODO: Realizar split train/test
pass

# %% [markdown]
# ## 3. Preprocessing
#
# ### TODO: Pré-processar dados
# - Normalizar features numéricas
# - Codificar features categóricas
# - Aplicar transformações

# %%
# TODO: Usar DataPreprocessor
# TODO: Fit no train, transform em test
# TODO: Verificar resultado
pass

# %% [markdown]
# ## 4. Feature Selection
#
# ### TODO: Seleção de features
# - Calcular importância das features
# - Selecionar top N features
# - Visualizar importância

# %%
# TODO: get_feature_importance
# TODO: Plot top features
pass

# %% [markdown]
# ## 5. Baseline Models
#
# ### TODO: Treinar baselines
# - Dummy Classifier (most_frequent)
# - Logistic Regression
# - Comparar performance

# %%
# TODO: DummyBaseline
# TODO: LogisticBaseline
# TODO: calculate_metrics para cada um
# TODO: Comparar resultados
pass

# %% [markdown]
# ## 6. MLP Model Training
#
# ### TODO: Treinar MLP
# - Preparar data loaders
# - Criar e treinar modelo
# - Usar early stopping

# %%
# TODO: Converter dados para tensors
# TODO: Criar DataLoaders
# TODO: Inicializar MLPClassifier
# TODO: Treinar com Trainer
pass

# %% [markdown]
# ## 7. Model Evaluation
#
# ### TODO: Avaliar modelos
# - Métricas de teste
# - Confusion matrix
# - ROC curve

# %%
# TODO: Predictions no test set
        
print("\nBest Model: MLP")
print(f"\nPerformance:")
print("- Accuracy: TODO")
print("- Precision: TODO")
print("- Recall: TODO")
print("- F1-Score: TODO")
print("- ROC-AUC: TODO")

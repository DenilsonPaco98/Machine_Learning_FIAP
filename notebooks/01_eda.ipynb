# %% [markdown]
# # Exploratory Data Analysis - Telco Customer Churn
#
# Neste notebook realizaremos uma análise exploratória completa dos dados de churn de clientes de telecomunicações.

# %% [markdown]
# ## 1. Imports e Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.config import RAW_DATA_DIR, DATASET_NAME, SEED
from src.data.preprocess import load_data

# Set random seed
np.random.seed(SEED)
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

# Load dataset
df = load_data(RAW_DATA_DIR / DATASET_NAME)
print(f"Dataset shape: {df.shape}")
print(f"\nFirst few rows:")
df.head()

# %% [markdown]
# ## 2. Dataset Overview
#
# ### TODO: Análise do dataset
# - Info do dataframe (tipos, missing values)
# - Estatísticas descritivas
# - Distribuição do target
# - Correlação entre features

# %%
# Análise de informações básicas
# TODO: df.info(), df.describe(), df.isnull().sum()
# Mostrar tipos de dados e missing values
pass

# %% [markdown]
# ## 3. Target Analysis
#
# ### TODO: Análise da variável target
# - Distribuição do churn
# - Proporção de classes
# - Visualização com plot

# %%
# Análise da variável target
# TODO: value_counts, proporções, visualization
pass

# %% [markdown]
# ## 4. Demographic Analysis
#
# ### TODO: Análise demográfica
# - Distribuição de age, gender
# - Relação entre demografía e churn
# - Visualizações (histogramas, boxplots)

# %%
# Análise demográfica
# TODO: Distribuições, relações com churn
pass

# %% [markdown]
# ## 5. Financial Analysis
#
# ### TODO: Análise financeira
# - Distribuição de monthly_charges, total_charges
# - Correlação com churn
# - Segmentação por valor

# %%
# Análise financeira
# TODO: monthly_charges, total_charges distributions
pass

# %% [markdown]
# ## 6. Contract Analysis
#
# ### TODO: Análise de contrato
# - Tipos de contrato
# - Tenure distribution
# - Impacto no churn

# %%
# Análise de contrato
# TODO: contract types, tenure analysis
pass

# %% [markdown]
# ## 7. Service Usage Analysis
#
# ### TODO: Análise de serviços
# - Internet service types
# - Serviços adicionais (tech support, online security)
# - Influência no churn

# %%
# Análise de serviços
# TODO: internet_service, additional services
pass

# %% [markdown]
# ## 8. Correlation Analysis
#
# ### TODO: Matriz de correlação
# - Correlação entre features numéricas
# - Correlação com target
# - Heatmap

# %%
# Análise de correlação
# TODO: correlation matrix, heatmap com target
pass

# %% [markdown]
# ## 9. Feature Relationships with Churn
#
# ### TODO: Relações com churn
# - Top features correlacionadas com churn
# - Visualizações para cada feature

# %%
# Relações com churn
# TODO: feature importance analysis, visualizações
pass

# %% [markdown]
# ## 10. Data Quality Issues
#
# ### TODO: Problemas de qualidade
# - Missing values
# - Outliers
# - Inconsistências

# %%
# Verificar qualidade dos dados
# TODO: missing values, outliers detection
pass

# %% [markdown]
# ## 11. Summary of Insights
#
# ### TODO: Resumo dos insights
# - Principais drivers de churn
# - Problemas de dados identificados
# - Recomendações para feature engineering
# - Próximos passos

# %%
# Resumo de insights
# TODO: Consolidar findings
print("\n=== SUMMARY OF EDA ===")
print("\nKey findings:")
print("1. TODO")
print("2. TODO")
print("3. TODO")
print("\nNext steps:")
print("- Feature engineering")
print("- Model baseline")
print("- Model training")
